# %% [markdown]
# <a href="https://colab.research.google.com/github/carolhr/text-in-audio/blob/master/text_in_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Transformando texto em audio

# %%
# !pip install gtts

# %%
from  gtts import gTTS

text_to_say = "this is a sample piece of text read by GTTS"

language = "en"

gTTS_object =   gTTS(text = text_to_say,
                  lang = language,
                   slow = False)

gTTS_object.save("/content/gtts.wav")

# %%
from IPython.display import Audio

Audio("/content/gtts.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
